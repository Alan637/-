# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\globalterrorismdb_0718dist.csv',encoding='charmap')
df
# Out:
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df=df.loc[:,['country_txt','region_txt','iyear','imonth','iday','latitude','longitude']]

# %%
df['accident_date'] = df.iday.astype('str')+'-'+df.imonth.astype('str')+'-'+df.iyear.astype('str')
df.head()
# Out:
#           country_txt                   region_txt  iyear  imonth  iday  \
# 0  Dominican Republic  Central America & Caribbean   1970       7     2
# 1              Mexico                North America   1970       0     0
# 2         Philippines               Southeast Asia   1970       1     0
# 3              Greece               Western Europe   1970       1     0
# 4               Japan                    East Asia   1970       1     0
#
#     latitude   longitude accident_date
# 0  18.456792  -69.951164      2-7-1970
# 1  19.371887  -99.086624      0-0-1970
# 2  15.478598  120.599741      0-1-1970
# 3  37.997490   23.762728      0-1-1970
# 4  33.580412  130.396361      0-1-1970

# %%
df=df.sort_values(by=['country_txt','region_txt','iyear','imonth','iday','latitude','longitude'])
df
# Out:
#         country_txt          region_txt  iyear  imonth  iday   latitude  \
# 1863    Afghanistan          South Asia   1973       5     1  34.516895
# 7627    Afghanistan          South Asia   1979       2    14  34.516895
# 9156    Afghanistan          South Asia   1979       8    27  33.542622
# 9218    Afghanistan          South Asia   1979       9     9  34.346722
# 31132   Afghanistan          South Asia   1987       5    31        NaN
# ...             ...                 ...    ...     ...   ...        ...
# 125189     Zimbabwe  Sub-Saharan Africa   2013      12    29 -20.172190
# 127886     Zimbabwe  Sub-Saharan Africa   2014       2    25 -17.829560
# 176881     Zimbabwe  Sub-Saharan Africa   2017       7    12 -17.832667
# 177097     Zimbabwe  Sub-Saharan Africa   2017       7    19 -17.864021
# 177106     Zimbabwe  Sub-Saharan Africa   2017       7    19 -17.833295
#
#         longitude accident_date
# 1863    69.147011      1-5-1973
# 7627    69.147011     14-2-1979
# 9156    68.415329     27-8-1979
# 9218    62.197315      9-9-1979
# 31132         NaN     31-5-1987
# ...           ...           ...
# 125189  28.581160    29-12-2013
# 127886  31.053909     25-2-2014
# 176881  30.933316     12-7-2017
# 177097  31.029813     19-7-2017
# 177106  30.933271     19-7-2017
#
# [181691 rows x 8 columns]

# %%
dffamcountries=df.country_txt.value_counts()
dffamcountries
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# Antigua and Barbuda        1
# New Hebrides               1
# St. Lucia                  1
# South Vietnam              1
# North Korea                1
# Name: country_txt, Length: 205, dtype: int64

# %%
dffamcountries.describe()
# Out:
# count      205.000000
# mean       886.297561
# std       2582.329894
# min          1.000000
# 25%         13.000000
# 50%         66.000000
# 75%        363.000000
# max      24636.000000
# Name: country_txt, dtype: float64

# %%
a,b=dffamcountries.quantile([0.25,0.75])[[0.25,0.75]]

# %%
countries=dffamcountries[(dffamcountries>a)*(dffamcountries<b)]
countries
# Out:
# Cameroon      332
# Honduras      323
# Bolivia       314
# Ireland       307
# Venezuela     293
#              ...
# Fiji           17
# Latvia         17
# Estonia        16
# Luxembourg     16
# Swaziland      16
# Name: country_txt, Length: 101, dtype: int64

# %%
dfwithquantile=df[df.country_txt.apply(lambda x: x in countries)]
dfwithquantile
# Out:
#        country_txt          region_txt  iyear  imonth  iday   latitude  \
# 13599      Albania      Eastern Europe   1981       5    23  41.327500
# 43171      Albania      Eastern Europe   1990       7     3  41.327500
# 48028      Albania      Eastern Europe   1991       9     8  42.357222
# 50654      Albania      Eastern Europe   1992       3    20  42.067500
# 50666      Albania      Eastern Europe   1992       3    21  41.327500
# ...            ...                 ...    ...     ...   ...        ...
# 125189    Zimbabwe  Sub-Saharan Africa   2013      12    29 -20.172190
# 127886    Zimbabwe  Sub-Saharan Africa   2014       2    25 -17.829560
# 176881    Zimbabwe  Sub-Saharan Africa   2017       7    12 -17.832667
# 177097    Zimbabwe  Sub-Saharan Africa   2017       7    19 -17.864021
# 177106    Zimbabwe  Sub-Saharan Africa   2017       7    19 -17.833295
#
#         longitude accident_date
# 13599   19.818889     23-5-1981
# 43171   19.818889      3-7-1990
# 48028   20.073056      8-9-1991
# 50654   19.513056     20-3-1992
# 50666   19.818889     21-3-1992
# ...           ...           ...
# 125189  28.581160    29-12-2013
# 127886  31.053909     25-2-2014
# 176881  30.933316     12-7-2017
# 177097  31.029813     19-7-2017
# 177106  30.933271     19-7-2017
#
# [9718 rows x 8 columns]

# %%
dfmonthstat=pd.DataFrame(dfwithquantile.imonth.value_counts()).reset_index()
dfmonthstat.rename(columns={'index': 'monthnumber', 'imonth': 'counter'},inplace=True)
dfmonthstat.sort_values(by=['monthnumber'])
dfmonthstat
# Out:
#     monthnumber  counter
# 0             7      897
# 1            10      889
# 2            11      852
# 3             3      846
# 4             8      830
# 5             9      813
# 6             5      812
# 7             6      783
# 8             4      783
# 9             1      760
# 10            2      731
# 11           12      720
# 12            0        2

# %%
dfnorm=dfmonthstat.apply(lambda x: (x-x.min())/(x.max()-x.min()))
dfnorm
# Out:
#     monthnumber   counter
# 0      0.583333  1.000000
# 1      0.833333  0.991061
# 2      0.916667  0.949721
# 3      0.250000  0.943017
# 4      0.666667  0.925140
# 5      0.750000  0.906145
# 6      0.416667  0.905028
# 7      0.500000  0.872626
# 8      0.333333  0.872626
# 9      0.083333  0.846927
# 10     0.166667  0.814525
# 11     1.000000  0.802235
# 12     0.000000  0.000000

# %%
dfnorm.counter.plot.hist()
dfnorm.monthnumber.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dfnorm.counter.plot(kind='kde')
dfnorm.monthnumber.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.normal(size=1000))
# Out:
# (array([  5.,  35., 127., 193., 257., 211., 120.,  36.,  14.,   2.]),
#  array([-2.95601504, -2.30787559, -1.65973613, -1.01159667, -0.36345722,
#          0.28468224,  0.9328217 ,  1.58096115,  2.22910061,  2.87724007,
#          3.52537952]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
X=np.array(dfnorm.monthnumber).reshape(-1,1)
Y=np.array(dfnorm.counter)

# %%
model=LinearRegression().fit(X,Y)

# %%
y_pred=model.predict(X)

# %%
y_pred
# Out:
# array([0.8666462 , 0.96757321, 1.00121554, 0.73207686, 0.90028854,
#        0.93393087, 0.79936153, 0.83300387, 0.7657192 , 0.66479219,
#        0.69843453, 1.03485788, 0.63114986])

# %%
Y
# Out:
# array([1.        , 0.99106145, 0.94972067, 0.94301676, 0.92513966,
#        0.90614525, 0.90502793, 0.8726257 , 0.8726257 , 0.84692737,
#        0.81452514, 0.80223464, 0.        ])

# %%
plt.scatter(X,Y)
plt.plot(X,y_pred,c='y',alpha=0.2)
